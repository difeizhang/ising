# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1.1 Energy Data: Error vs. Number of Data

# %%
def plot_error_vs_numsamples(data, ax, label):
    ax.plot(data['numsamples'], data['mean'], label=label)
    ax.fill_between(data['numsamples'], data['mean'] - data['std'], data['mean'] + data['std'], alpha=0.3)
def superplot(L=4):
    data_error_vs_numsample_histogram_SL = np.load(f'./overleaf/e/L={L}/error_vs_numsample_histogram_SL.npz')
    data_error_vs_numsample_histogram_LBC = np.load(f'./overleaf/e/L={L}/error_vs_numsample_histogram_LBC.npz')
    data_error_vs_numsample_histogram_PBM = np.load(f'./overleaf/e/L={L}/error_vs_numsample_histogram_PBM.npz')
    data_error_vs_numsample_discriminative_SL = np.load(f'./overleaf/e/L={L}/error_vs_numsample_discriminative_SL.npz')
    data_error_vs_numsample_discriminative_LBC = np.load(f'./overleaf/e/L={L}/error_vs_numsample_discriminative_LBC.npz')
    data_error_vs_numsample_discriminative_PBM = np.load(f'./overleaf/e/L={L}/error_vs_numsample_discriminative_PBM.npz')
    data_error_vs_numsample_generative_SL = np.load(f'./overleaf/e/L={L}/error_vs_numsample_generative_SL.npz')
    data_error_vs_numsample_generative_LBC = np.load(f'./overleaf/e/L={L}/error_vs_numsample_generative_LBC.npz')
    data_error_vs_numsample_generative_PBM = np.load(f'./overleaf/e/L={L}/error_vs_numsample_generative_PBM.npz')

    fig, axs = plt.subplots(1, 3, figsize=(18, 4))
    plot_error_vs_numsamples(data_error_vs_numsample_histogram_SL, axs[0], 'histogram')
    plot_error_vs_numsamples(data_error_vs_numsample_discriminative_SL, axs[0], 'MLP')
    plot_error_vs_numsamples(data_error_vs_numsample_generative_SL, axs[0], 'PixelCNN')
    plot_error_vs_numsamples(data_error_vs_numsample_histogram_LBC, axs[1], 'histogram')
    plot_error_vs_numsamples(data_error_vs_numsample_discriminative_LBC, axs[1], 'MLP')
    plot_error_vs_numsamples(data_error_vs_numsample_generative_LBC, axs[1], 'PixelCNN')
    plot_error_vs_numsamples(data_error_vs_numsample_histogram_PBM, axs[2], 'histogram')
    plot_error_vs_numsamples(data_error_vs_numsample_discriminative_PBM, axs[2], 'MLP')
    plot_error_vs_numsamples(data_error_vs_numsample_generative_PBM, axs[2], 'PixelCNN')

    titles = ['SL', 'LBC', 'PBM']
    for ax, title in zip(axs, titles):
        ax.set_xscale('log')
        ax.set_yscale('log')
        ax.set_xlabel('Number of samples')
        ax.set_ylabel('Error')
        ax.set_title(title)
        ax.legend()
    plt.tight_layout()
    plt.show()

# %%
superplot(L=4)
superplot(L=3)
superplot(L=8)

# %% [markdown]
# ## 1.2 State Data: Error vs. Number of Data

# %%
def superplot(L=4):
    data_error_vs_numsample_histogram_SL = np.load(f'./overleaf/s/L={L}/error_vs_numsample_histogram_SL.npz')
    data_error_vs_numsample_histogram_LBC = np.load(f'./overleaf/s/L={L}/error_vs_numsample_histogram_LBC.npz')
    data_error_vs_numsample_histogram_PBM = np.load(f'./overleaf/s/L={L}/error_vs_numsample_histogram_PBM.npz')
    data_error_vs_numsample_discriminative_SL = np.load(f'./overleaf/s/L={L}/error_vs_numsample_discriminative_SL.npz')
    data_error_vs_numsample_discriminative_LBC = np.load(f'./overleaf/s/L={L}/error_vs_numsample_discriminative_LBC.npz')
    data_error_vs_numsample_discriminative_PBM = np.load(f'./overleaf/s/L={L}/error_vs_numsample_discriminative_PBM.npz')
    data_error_vs_numsample_generative_SL = np.load(f'./overleaf/s/L={L}/error_vs_numsample_generative_SL.npz')
    data_error_vs_numsample_generative_LBC = np.load(f'./overleaf/s/L={L}/error_vs_numsample_generative_LBC.npz')
    data_error_vs_numsample_generative_PBM = np.load(f'./overleaf/s/L={L}/error_vs_numsample_generative_PBM.npz')

    fig, axs = plt.subplots(1, 3, figsize=(18, 4))
    plot_error_vs_numsamples(data_error_vs_numsample_histogram_SL, axs[0], 'histogram')
    plot_error_vs_numsamples(data_error_vs_numsample_discriminative_SL, axs[0], 'MLP')
    plot_error_vs_numsamples(data_error_vs_numsample_generative_SL, axs[0], 'PixelCNN')
    plot_error_vs_numsamples(data_error_vs_numsample_histogram_LBC, axs[1], 'histogram')
    plot_error_vs_numsamples(data_error_vs_numsample_discriminative_LBC, axs[1], 'MLP')
    plot_error_vs_numsamples(data_error_vs_numsample_generative_LBC, axs[1], 'PixelCNN')
    plot_error_vs_numsamples(data_error_vs_numsample_histogram_PBM, axs[2], 'histogram')
    plot_error_vs_numsamples(data_error_vs_numsample_discriminative_PBM, axs[2], 'MLP')
    plot_error_vs_numsamples(data_error_vs_numsample_generative_PBM, axs[2], 'PixelCNN')

    titles = ['SL', 'LBC', 'PBM']
    for ax, title in zip(axs, titles):
        ax.set_xscale('log')
        ax.set_yscale('log')
        ax.set_xlabel('Number of samples')
        ax.set_ylabel('Error')
        ax.set_title(title)
        ax.legend()
    plt.tight_layout()
    plt.show()

# %%
superplot(L=4)
superplot(L=3)
superplot(L=8)

# %% [markdown]
# ## 2.1 Energy Data: Error vs. Training Time

# %%
def plot_error_vs_time(data, ax, label, mode='normal'):
    if mode == 'normal':
        ax.plot(data['time'], data['mean'], label=label)
        ax.fill_between(data['time'], data['mean'] - data['std'], data['mean'] + data['std'], alpha=0.3)
    elif mode == 'envelope':
        ax.plot(data['time'], data['error_env'], label=label)
    elif mode == 'scatter':
        ax.scatter(data['time_scatters'], data['error_scatters'], label=label, s=1, alpha=0.5)
    else:
        raise ValueError('Invalid mode')

# %% [markdown]
# ### a. Without Date Generation Time (SKIP)

# %%
data_error_vs_time_histogram_SL = np.load('./overleaf/e/error_vs_time_histogram_SL.npz')
data_error_vs_time_histogram_LBC = np.load('./overleaf/e/error_vs_time_histogram_LBC.npz')
data_error_vs_time_histogram_PBM = np.load('./overleaf/e/error_vs_time_histogram_PBM.npz')
data_error_vs_time_discriminative_SL = np.load('./overleaf/e/error_vs_time_discriminative_SL.npz')
data_error_vs_time_discriminative_LBC = np.load('./overleaf/e/error_vs_time_discriminative_LBC.npz')
data_error_vs_time_discriminative_PBM = np.load('./overleaf/e/error_vs_time_discriminative_PBM.npz')
data_error_vs_time_generative_SL = np.load('./overleaf/e/error_vs_time_generative_SL.npz')
data_error_vs_time_generative_LBC = np.load('./overleaf/e/error_vs_time_generative_LBC.npz')
data_error_vs_time_generative_PBM = np.load('./overleaf/e/error_vs_time_generative_PBM.npz')

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 4))
plot_error_vs_time(data_error_vs_time_histogram_SL, axs[0], 'histogram')
plot_error_vs_time(data_error_vs_time_discriminative_SL, axs[0], 'MLP envelope', mode='envelope')
plot_error_vs_time(data_error_vs_time_discriminative_SL, axs[0], 'MLP scatter', mode='scatter')
plot_error_vs_time(data_error_vs_time_generative_SL, axs[0], 'PixelCNN envelope', mode='envelope')
plot_error_vs_time(data_error_vs_time_generative_SL, axs[0], 'PixelCNN scatter', mode='scatter')


plot_error_vs_time(data_error_vs_time_histogram_LBC, axs[1], 'histogram')
plot_error_vs_time(data_error_vs_time_discriminative_LBC, axs[1], 'MLP envelope', mode='envelope')
plot_error_vs_time(data_error_vs_time_discriminative_LBC, axs[1], 'MLP scatter', mode='scatter')
plot_error_vs_time(data_error_vs_time_generative_LBC, axs[1], 'PixelCNN envelope', mode='envelope')
plot_error_vs_time(data_error_vs_time_generative_LBC, axs[1], 'PixelCNN scatter', mode='scatter')

plot_error_vs_time(data_error_vs_time_histogram_PBM, axs[2], 'histogram')
plot_error_vs_time(data_error_vs_time_discriminative_PBM, axs[2], 'MLP envelope', mode='envelope')
plot_error_vs_time(data_error_vs_time_discriminative_PBM, axs[2], 'MLP scatter', mode='scatter')
plot_error_vs_time(data_error_vs_time_generative_PBM, axs[2], 'PixelCNN envelope', mode='envelope')
plot_error_vs_time(data_error_vs_time_generative_PBM, axs[2], 'PixelCNN scatter', mode='scatter')

titles = ['SL', 'LBC', 'PBM']
for ax, title in zip(axs, titles):
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.set_xlabel('Time (s)')
    ax.set_ylabel('Error')
    ax.set_title(title)
    ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### b. With Date Generation Time

# %%
def superplot(L=4):
    data_error_vs_time_histogram_SL = np.load(f'./overleaf/e/L={L}/error_vs_time_histogram_SL_include.npz')
    data_error_vs_time_histogram_LBC = np.load(f'./overleaf/e/L={L}/error_vs_time_histogram_LBC_include.npz')
    data_error_vs_time_histogram_PBM = np.load(f'./overleaf/e/L={L}/error_vs_time_histogram_PBM_include.npz')
    data_error_vs_time_discriminative_SL = np.load(f'./overleaf/e/L={L}/error_vs_time_discriminative_SL_include.npz')
    data_error_vs_time_discriminative_LBC = np.load(f'./overleaf/e/L={L}/error_vs_time_discriminative_LBC_include.npz')
    data_error_vs_time_discriminative_PBM = np.load(f'./overleaf/e/L={L}/error_vs_time_discriminative_PBM_include.npz')
    data_error_vs_time_generative_SL = np.load(f'./overleaf/e/L={L}/error_vs_time_generative_SL_include.npz')
    data_error_vs_time_generative_LBC = np.load(f'./overleaf/e/L={L}/error_vs_time_generative_LBC_include.npz')
    data_error_vs_time_generative_PBM = np.load(f'./overleaf/e/L={L}/error_vs_time_generative_PBM_include.npz')

    fig, axs = plt.subplots(1, 3, figsize=(18, 4))
    plot_error_vs_time(data_error_vs_time_histogram_SL, axs[0], 'histogram')
    plot_error_vs_time(data_error_vs_time_discriminative_SL, axs[0], 'MLP envelope', mode='envelope')
    plot_error_vs_time(data_error_vs_time_discriminative_SL, axs[0], 'MLP scatter', mode='scatter')
    plot_error_vs_time(data_error_vs_time_generative_SL, axs[0], 'PixelCNN envelope', mode='envelope')
    plot_error_vs_time(data_error_vs_time_generative_SL, axs[0], 'PixelCNN scatter', mode='scatter')

    plot_error_vs_time(data_error_vs_time_histogram_LBC, axs[1], 'histogram')
    plot_error_vs_time(data_error_vs_time_discriminative_LBC, axs[1], 'MLP envelope', mode='envelope')
    plot_error_vs_time(data_error_vs_time_discriminative_LBC, axs[1], 'MLP scatter', mode='scatter')
    plot_error_vs_time(data_error_vs_time_generative_LBC, axs[1], 'PixelCNN envelope', mode='envelope')
    plot_error_vs_time(data_error_vs_time_generative_LBC, axs[1], 'PixelCNN scatter', mode='scatter')

    plot_error_vs_time(data_error_vs_time_histogram_PBM, axs[2], 'histogram')
    plot_error_vs_time(data_error_vs_time_discriminative_PBM, axs[2], 'MLP envelope', mode='envelope')
    plot_error_vs_time(data_error_vs_time_discriminative_PBM, axs[2], 'MLP scatter', mode='scatter')
    plot_error_vs_time(data_error_vs_time_generative_PBM, axs[2], 'PixelCNN envelope', mode='envelope')
    plot_error_vs_time(data_error_vs_time_generative_PBM, axs[2], 'PixelCNN scatter', mode='scatter')

    titles = ['SL', 'LBC', 'PBM']
    for ax, title in zip(axs, titles):
        ax.set_xscale('log')
        ax.set_yscale('log')
        ax.set_xlabel('Time (s)')
        ax.set_ylabel('Error')
        ax.set_title(title)
        ax.legend()
    plt.tight_layout()
    plt.show()

# %%
superplot(L=4)
superplot(L=3)
superplot(L=8)

# %% [markdown]
# ## 2.2 State Data: Error vs. Training Time

# %% [markdown]
# ### a. Without Date Generation Time (SKIP)

# %%
data_error_vs_time_histogram_SL = np.load('./overleaf/s/error_vs_time_histogram_SL.npz')
data_error_vs_time_histogram_LBC = np.load('./overleaf/s/error_vs_time_histogram_LBC.npz')
data_error_vs_time_histogram_PBM = np.load('./overleaf/s/error_vs_time_histogram_PBM.npz')
data_error_vs_time_discriminative_SL = np.load('./overleaf/s/error_vs_time_discriminative_SL.npz')
data_error_vs_time_discriminative_LBC = np.load('./overleaf/s/error_vs_time_discriminative_LBC.npz')
data_error_vs_time_discriminative_PBM = np.load('./overleaf/s/error_vs_time_discriminative_PBM.npz')
data_error_vs_time_generative_SL = np.load('./overleaf/s/error_vs_time_generative_SL.npz')
data_error_vs_time_generative_LBC = np.load('./overleaf/s/error_vs_time_generative_LBC.npz')
data_error_vs_time_generative_PBM = np.load('./overleaf/s/error_vs_time_generative_PBM.npz')

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 4))
plot_error_vs_time(data_error_vs_time_histogram_SL, axs[0], 'histogram')
plot_error_vs_time(data_error_vs_time_discriminative_SL, axs[0], 'MLP envelope', mode='envelope')
plot_error_vs_time(data_error_vs_time_discriminative_SL, axs[0], 'MLP scatter', mode='scatter')
plot_error_vs_time(data_error_vs_time_generative_SL, axs[0], 'PixelCNN envelope', mode='envelope')
plot_error_vs_time(data_error_vs_time_generative_SL, axs[0], 'PixelCNN scatter', mode='scatter')


plot_error_vs_time(data_error_vs_time_histogram_LBC, axs[1], 'histogram')
plot_error_vs_time(data_error_vs_time_discriminative_LBC, axs[1], 'MLP envelope', mode='envelope')
plot_error_vs_time(data_error_vs_time_discriminative_LBC, axs[1], 'MLP scatter', mode='scatter')
plot_error_vs_time(data_error_vs_time_generative_LBC, axs[1], 'PixelCNN envelope', mode='envelope')
plot_error_vs_time(data_error_vs_time_generative_LBC, axs[1], 'PixelCNN scatter', mode='scatter')

plot_error_vs_time(data_error_vs_time_histogram_PBM, axs[2], 'histogram')
plot_error_vs_time(data_error_vs_time_discriminative_PBM, axs[2], 'MLP envelope', mode='envelope')
plot_error_vs_time(data_error_vs_time_discriminative_PBM, axs[2], 'MLP scatter', mode='scatter')
plot_error_vs_time(data_error_vs_time_generative_PBM, axs[2], 'PixelCNN envelope', mode='envelope')
plot_error_vs_time(data_error_vs_time_generative_PBM, axs[2], 'PixelCNN scatter', mode='scatter')

titles = ['SL', 'LBC', 'PBM']
for ax, title in zip(axs, titles):
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.set_xlabel('Time (s)')
    ax.set_ylabel('Error')
    ax.set_title(title)
    ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### b. With Date Generation Time

# %%
def superplot(L=4):
    data_error_vs_time_histogram_SL = np.load(f'./overleaf/s/L={L}/error_vs_time_histogram_SL_include.npz')
    data_error_vs_time_histogram_LBC = np.load(f'./overleaf/s/L={L}/error_vs_time_histogram_LBC_include.npz')
    data_error_vs_time_histogram_PBM = np.load(f'./overleaf/s/L={L}/error_vs_time_histogram_PBM_include.npz')
    data_error_vs_time_discriminative_SL = np.load(f'./overleaf/s/L={L}/error_vs_time_discriminative_SL_include.npz')
    data_error_vs_time_discriminative_LBC = np.load(f'./overleaf/s/L={L}/error_vs_time_discriminative_LBC_include.npz')
    data_error_vs_time_discriminative_PBM = np.load(f'./overleaf/s/L={L}/error_vs_time_discriminative_PBM_include.npz')
    data_error_vs_time_generative_SL = np.load(f'./overleaf/s/L={L}/error_vs_time_generative_SL_include.npz')
    data_error_vs_time_generative_LBC = np.load(f'./overleaf/s/L={L}/error_vs_time_generative_LBC_include.npz')
    data_error_vs_time_generative_PBM = np.load(f'./overleaf/s/L={L}/error_vs_time_generative_PBM_include.npz')

    fig, axs = plt.subplots(1, 3, figsize=(18, 4))
    plot_error_vs_time(data_error_vs_time_histogram_SL, axs[0], 'histogram')
    plot_error_vs_time(data_error_vs_time_discriminative_SL, axs[0], 'MLP envelope', mode='envelope')
    plot_error_vs_time(data_error_vs_time_discriminative_SL, axs[0], 'MLP scatter', mode='scatter')
    plot_error_vs_time(data_error_vs_time_generative_SL, axs[0], 'PixelCNN envelope', mode='envelope')
    plot_error_vs_time(data_error_vs_time_generative_SL, axs[0], 'PixelCNN scatter', mode='scatter')

    plot_error_vs_time(data_error_vs_time_histogram_LBC, axs[1], 'histogram')
    plot_error_vs_time(data_error_vs_time_discriminative_LBC, axs[1], 'MLP envelope', mode='envelope')
    plot_error_vs_time(data_error_vs_time_discriminative_LBC, axs[1], 'MLP scatter', mode='scatter')
    plot_error_vs_time(data_error_vs_time_generative_LBC, axs[1], 'PixelCNN envelope', mode='envelope')
    plot_error_vs_time(data_error_vs_time_generative_LBC, axs[1], 'PixelCNN scatter', mode='scatter')

    plot_error_vs_time(data_error_vs_time_histogram_PBM, axs[2], 'histogram')
    plot_error_vs_time(data_error_vs_time_discriminative_PBM, axs[2], 'MLP envelope', mode='envelope')
    plot_error_vs_time(data_error_vs_time_discriminative_PBM, axs[2], 'MLP scatter', mode='scatter')
    plot_error_vs_time(data_error_vs_time_generative_PBM, axs[2], 'PixelCNN envelope', mode='envelope')
    plot_error_vs_time(data_error_vs_time_generative_PBM, axs[2], 'PixelCNN scatter', mode='scatter')

    titles = ['SL', 'LBC', 'PBM']
    for ax, title in zip(axs, titles):
        ax.set_xscale('log')
        ax.set_yscale('log')
        ax.set_xlabel('Time (s)')
        ax.set_ylabel('Error')
        ax.set_title(title)
        ax.legend()
    plt.tight_layout()
    plt.show()

# %%
superplot(L=4)
superplot(L=3)
superplot(L=8)

# %% [markdown]
# ## 3. Comparison of Energy and State Data (With Data Generation Time, Without Scaling Down LBC points)

# %%
s_data_error_vs_time_histogram_SL = np.load('./overleaf/compare/S_error_vs_time_histogram_SL_include.npz')
s_data_error_vs_time_discriminative_SL = np.load('./overleaf/compare/S_error_vs_time_discriminative_SL_include.npz')
s_data_error_vs_time_generative_SL = np.load('./overleaf/compare/S_error_vs_time_generative_SL_include.npz')
e_data_error_vs_time_histogram_SL = np.load('./overleaf/compare/E_error_vs_time_histogram_SL_include.npz')
e_data_error_vs_time_discriminative_SL = np.load('./overleaf/compare/E_error_vs_time_discriminative_SL_include.npz')
e_data_error_vs_time_generative_SL = np.load('./overleaf/compare/E_error_vs_time_generative_SL_include.npz')

s_data_error_vs_time_histogram_LBC = np.load('./overleaf/compare/S_error_vs_time_histogram_LBC_include.npz')
s_data_error_vs_time_discriminative_LBC = np.load('./overleaf/compare/S_error_vs_time_discriminative_LBC_include.npz')
s_data_error_vs_time_generative_LBC = np.load('./overleaf/compare/S_error_vs_time_generative_LBC_include.npz')
e_data_error_vs_time_histogram_LBC = np.load('./overleaf/compare/E_error_vs_time_histogram_LBC_include.npz')
e_data_error_vs_time_discriminative_LBC = np.load('./overleaf/compare/E_error_vs_time_discriminative_LBC_include.npz')
e_data_error_vs_time_generative_LBC = np.load('./overleaf/compare/E_error_vs_time_generative_LBC_include.npz')

s_data_error_vs_time_histogram_PBM = np.load('./overleaf/compare/S_error_vs_time_histogram_PBM_include.npz')
s_data_error_vs_time_discriminative_PBM = np.load('./overleaf/compare/S_error_vs_time_discriminative_PBM_include.npz')
s_data_error_vs_time_generative_PBM = np.load('./overleaf/compare/S_error_vs_time_generative_PBM_include.npz')
e_data_error_vs_time_histogram_PBM = np.load('./overleaf/compare/E_error_vs_time_histogram_PBM_include.npz')
e_data_error_vs_time_discriminative_PBM = np.load('./overleaf/compare/E_error_vs_time_discriminative_PBM_include.npz')
e_data_error_vs_time_generative_PBM = np.load('./overleaf/compare/E_error_vs_time_generative_PBM_include.npz')

fig, axs = plt.subplots(1, 3, figsize=(18, 4))
plot_error_vs_time(s_data_error_vs_time_histogram_SL, axs[0], 'hist-s')
plot_error_vs_time(e_data_error_vs_time_histogram_SL, axs[0], 'hist-e')
plot_error_vs_time(s_data_error_vs_time_discriminative_SL, axs[0], 'cnn-s', mode='envelope')
plot_error_vs_time(e_data_error_vs_time_discriminative_SL, axs[0], 'mlp-e', mode='envelope')
plot_error_vs_time(s_data_error_vs_time_generative_SL, axs[0], 'pcnn-s', mode='envelope')
plot_error_vs_time(e_data_error_vs_time_generative_SL, axs[0], 'pcnn-e', mode='envelope')

plot_error_vs_time(s_data_error_vs_time_histogram_LBC, axs[1], 'hist-s')
plot_error_vs_time(e_data_error_vs_time_histogram_LBC, axs[1], 'hist-e')
plot_error_vs_time(s_data_error_vs_time_discriminative_LBC, axs[1], 'cnn-s', mode='envelope')
plot_error_vs_time(e_data_error_vs_time_discriminative_LBC, axs[1], 'mlp-e', mode='envelope')
plot_error_vs_time(s_data_error_vs_time_generative_LBC, axs[1], 'pcnn-s', mode='envelope')
plot_error_vs_time(e_data_error_vs_time_generative_LBC, axs[1], 'pcnn-e', mode='envelope')

plot_error_vs_time(s_data_error_vs_time_histogram_PBM, axs[2], 'hist-s')
plot_error_vs_time(e_data_error_vs_time_histogram_PBM, axs[2], 'hist-e')
plot_error_vs_time(s_data_error_vs_time_discriminative_PBM, axs[2], 'cnn-s', mode='envelope')
plot_error_vs_time(e_data_error_vs_time_discriminative_PBM, axs[2], 'mlp-e', mode='envelope')
plot_error_vs_time(s_data_error_vs_time_generative_PBM, axs[2], 'pcnn-s', mode='envelope')
plot_error_vs_time(e_data_error_vs_time_generative_PBM, axs[2], 'pcnn-e', mode='envelope')

titles = ['SL', 'LBC', 'PBM']
for ax, title in zip(axs, titles):
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.set_xlabel('Time (s)')
    ax.set_ylabel('Error')
    ax.set_title(title)
    ax.legend()
plt.tight_layout()

plt.show()

# %% [markdown]
# ## 4. Compare LBC results (with data generation time), scaled by number of LBC points

# %%
s_data_error_vs_time_histogram_LBC = np.load('./overleaf/lbc_compare/S_error_vs_time_histogram_LBC_include.npz')
s_data_error_vs_time_discriminative_LBC = np.load('./overleaf/lbc_compare/S_error_vs_time_discriminative_LBC_include.npz')
s_data_error_vs_time_generative_LBC = np.load('./overleaf/lbc_compare/S_error_vs_time_generative_LBC_include.npz')
e_data_error_vs_time_histogram_LBC = np.load('./overleaf/lbc_compare/E_error_vs_time_histogram_LBC_include.npz')
e_data_error_vs_time_discriminative_LBC = np.load('./overleaf/lbc_compare/E_error_vs_time_discriminative_LBC_include.npz')
e_data_error_vs_time_generative_LBC = np.load('./overleaf/lbc_compare/E_error_vs_time_generative_LBC_include.npz')

# %%
fig, axs = plt.subplots(1, 1, figsize=(6, 4))
plot_error_vs_time(s_data_error_vs_time_histogram_LBC, axs, 'hist-s')
plot_error_vs_time(s_data_error_vs_time_discriminative_LBC, axs, 'cnn-s', mode='envelope')
plot_error_vs_time(s_data_error_vs_time_generative_LBC, axs, 'pixelcnn-s', mode='envelope')
plot_error_vs_time(e_data_error_vs_time_histogram_LBC, axs, 'hist-e')
plot_error_vs_time(e_data_error_vs_time_discriminative_LBC, axs, 'cnn-e', mode='envelope')
plot_error_vs_time(e_data_error_vs_time_generative_LBC, axs, 'pixelcnn-e', mode='envelope')

axs.set_xscale('log')
axs.set_yscale('log')
axs.set_xlabel('Time (s)')
axs.set_ylabel('Error')
axs.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Model Size

# %% [markdown]
# ### energy

# %%
data_error_vs_numsample_large_discriminative_LBC = np.load('./appendix/E_Large_error_vs_numsample_Discriminative_LBC.npz')
data_error_vs_numsample_large_generative_LBC = np.load('./appendix/E_Large_error_vs_numsample_Generative_LBC.npz')
data_error_vs_numsample_small_discriminative_LBC = np.load('./appendix/E_Small_error_vs_numsample_Discriminative_LBC.npz')
data_error_vs_numsample_small_generative_LBC = np.load('./appendix/E_Small_error_vs_numsample_Generative_LBC.npz')

# %%
fig, ax = plt.subplots(1, 1, figsize=(4, 4))
plot_error_vs_numsamples(data_error_vs_numsample_large_discriminative_LBC, ax, 'mlp')
plot_error_vs_numsamples(data_error_vs_numsample_small_discriminative_LBC, ax, 'mlp-small')
plot_error_vs_numsamples(data_error_vs_numsample_large_generative_LBC, ax, 'gen')
plot_error_vs_numsamples(data_error_vs_numsample_small_generative_LBC, ax, 'gen-small')

title = 'LBC'

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Number of samples')
ax.set_ylabel('Error')
ax.set_title(title)
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### states

# %%
data_error_vs_numsample_large_discriminative_LBC = np.load('./appendix/S_Large_error_vs_numsample_Discriminative_LBC.npz')
data_error_vs_numsample_large_generative_LBC = np.load('./appendix/S_Large_error_vs_numsample_Generative_LBC.npz')
data_error_vs_numsample_small_discriminative_LBC = np.load('./appendix/S_Small_error_vs_numsample_Discriminative_LBC.npz')
data_error_vs_numsample_small_generative_LBC = np.load('./appendix/S_Small_error_vs_numsample_Generative_LBC.npz')

# %%
fig, ax = plt.subplots(1, 1, figsize=(4, 4))
plot_error_vs_numsamples(data_error_vs_numsample_large_discriminative_LBC, ax, 'cnn')
plot_error_vs_numsamples(data_error_vs_numsample_small_discriminative_LBC, ax, 'cnn-small')
plot_error_vs_numsamples(data_error_vs_numsample_large_generative_LBC, ax, 'gen')
plot_error_vs_numsamples(data_error_vs_numsample_small_generative_LBC, ax, 'gen-small')

title = 'LBC'

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Number of samples')
ax.set_ylabel('Error')
ax.set_title(title)
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # PixelCNN reproduce E_mean and M_mean

# %%
E_Boltzmann = np.load('./appendix/E_Boltzmann.npy')
M_Boltzmann = np.load('./appendix/M_Boltzmann.npy')
E_FKL = np.load('./appendix/E_FKL.npy')
M_FKL = np.load('./appendix/M_FKL.npy')
E_RKL = np.load('./appendix/E_RKL.npy')
M_RKL = np.load('./appendix/M_RKL.npy')
T = np.linspace(0.1,5.1, 51)

# %%
fig, axs = plt.subplots(1,2, figsize=(10,3))
axs[0].plot(T, E_Boltzmann, label = 'Boltzmann', color = 'k')
axs[0].plot(T, E_FKL, label = 'forward kl pixelcnn', marker = '.',  color = 'red')
axs[0].plot(T, E_RKL, label = 'reverse kl pixelcnn', linestyle = 'dashed', color = 'b')
axs[0].set_xlabel('Temperature')
axs[0].set_ylabel('<E>')
axs[0].legend()

axs[1].plot(T, M_Boltzmann, label = 'Boltzmann', color = 'k')
axs[1].plot(T, M_FKL, label = 'forward kl pixelcnn', marker = '.',  color = 'red')
axs[1].plot(T, M_RKL, label = 'reverse kl pixelcnn', linestyle = 'dashed', color = 'b')
axs[1].set_xlabel('Temperature')
axs[1].set_ylabel('<M>')
axs[1].legend()

plt.show()
